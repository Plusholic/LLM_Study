# %%
from typing import Optional, List, Dict

import os
import openai
openai.api_key = os.environ["OPENAI_API_KEY"]

from langchain.schema import Document
from langchain.document_loaders import UnstructuredExcelLoader
from langchain.document_loaders import PyPDFLoader
from langchain.document_loaders.base import BaseLoader
from langchain.document_loaders.csv_loader import UnstructuredCSVLoader
from langchain.document_loaders import PyPDFDirectoryLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS, Chroma #pip install chromadb==0.4.15
from langchain.chains import RetrievalQA
from langchain.llms import OpenAI

# %%
import csv
columns_to_embed = ["주제","도메인","논문명","IF"]
columns_to_metadata = ["행","저널명"]
docs = []
with open('/Users/jeonjunhwi/문서/Projects/GNN_Covid/refference/GNN 논문리스트.csv', newline="", encoding='utf-8-sig') as csvfile:
    csv_reader = csv.DictReader(csvfile)
    for i, row in enumerate(csv_reader):
        to_metadata = {col: row[col] for col in columns_to_metadata if col in row}
        values_to_embed = {k: row[k] for k in columns_to_embed if k in row}
        to_embed = "\n".join(f"{k.strip()}: {v.strip()}" for k, v in values_to_embed.items())
        newDoc = Document(page_content=to_embed, metadata=to_metadata)
        docs.append(newDoc)
        
splitter = CharacterTextSplitter(separator = "\n",
                                chunk_size=500, 
                                chunk_overlap=0,
                                length_function=len)
documents = splitter.split_documents(docs)

# %%
from langchain.chains.query_constructor.base import AttributeInfo
from langchain.chat_models import ChatOpenAI
from langchain.retrievers.self_query.base import SelfQueryRetriever
from langchain.agents import create_pandas_dataframe_agent

llm=ChatOpenAI(temperature=0)
metadata_field_info=[
     AttributeInfo(
        name="주제",
        description="Indicates the subject category of the paper", 
        type="string", 
    ),
    AttributeInfo(
        name="도메인",
        description="Indicates what data was used in the paper", 
        type="string", 
    ),
    AttributeInfo(
        name="논문명",
        description="Indicates what data was used in the paper", 
        type="string", 
    ),
    AttributeInfo(
        name="IF",
        description="Indicates the impact factor of the journal in which the paper is published", 
        type="float", 
    ),
    AttributeInfo(
        name="저널명",
        description="Represents the journal in which the paper was published", 
        type="string", 
    ),
]
# https://www.neum.ai/post/llm-spreadsheets
# vectorstore = FAISS.from_documents(documents, OpenAIEmbeddings())
vectorstore = Chroma.from_documents(documents,
                                    OpenAIEmbeddings(),
                                    persist_directory='./Retrieval_Database/Vector_Database/paper_info_chroma_openai_128_sentence_splitter')
document_content_description = "Graph natural network paper list and information for each paper"
retriever = SelfQueryRetriever.from_llm(
    llm, vectorstore, document_content_description, metadata_field_info, search_kwargs={"k": 4},verbose=True
)

# %%
retriever.get_relevant_documents("dropedge?")
# Out:
# [Document(page_content='주제: Model\n도메인: \n논문명: DROPEDGE: TOWARDS DEEP GRAPH CONVOLU- TIONAL NETWORKS ON NODE CLASSIFICATION\nIF:', metadata={'저널명': 'arXiv ', '행': '29'}),
#  Document(page_content='주제: Model\n도메인: \n논문명: A Graph Convolutional Incorporating GRU Network for Landslide Displacement Forecasting Based on Spatiotemporal Analysis of GNSS Observations\nIF: 5.349', metadata={'저널명': 'MDPI remote sensing', '행': '56'}),
#  Document(page_content='주제: Model\n도메인: Traffic\n논문명: Graph-GAN: A spatial-temporal neural network for short-term passenger flow prediction in urban rail transit systems\nIF: 9.69', metadata={'저널명': 'transportation research part c', '행': '6'}),
#  Document(page_content='주제: \n도메인: Covid\n논문명: Transportation, germs, culture: a dynamic graph model of COVID-19 outbreak\nIF: 3.54', metadata={'저널명': 'Quantitative Biology', '행': '73'})]

# %%
loader = UnstructuredExcelLoader("/Users/jeonjunhwi/문서/Projects/GNN_Covid/refference/GNN 논문리스트.xlsx", mode="elements")
documents = loader.load()

text_splitter = CharacterTextSplitter(chunk_size=256, chunk_overlap=30, separator="\n")
docs = text_splitter.split_documents(documents=documents)

embeddings = OpenAIEmbeddings()
vectorstore = FAISS.from_documents(docs, embeddings)

qa = RetrievalQA.from_chain_type(llm=OpenAI(),
                                 chain_type='refine',
                                 retriever = vectorstore.as_retriever(search_kwargs={"k": 4}),
                                 return_source_documents=True
                                 )

# %%
loader = UnstructuredCSVLoader(
    file_path="/Users/jeonjunhwi/문서/Projects/GNN_Covid/refference/GNN 논문리스트.csv", mode="elements"
)
docs = loader.load()

# %%
print(docs[0].metadata['text_as_html'])
# Out:
# <table border="1" class="dataframe">
#   <tbody>
#     <tr>
#       <td></td>
#       <td>주제</td>
#       <td>도메인</td>
#       <td>논문명</td>
#       <td>IF</td>
#       <td>저널명</td>
#     </tr>
#     <tr>
#       <td>1.0</td>
#       <td></td>
#       <td>Covid, weather</td>
#       <td>The impact of weather condition and social activity on COVID-19 transmission in the United States</td>
#       <td>6.789</td>
#       <td>Journal of Environmental Management</td>
#     </tr>
#     <tr>
#       <td>2.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>A deep spatio-temporal meta-learning model for urban traffic revitalization index prediction in the COVID-19 pandemic</td>
#       <td>5.603</td>
#       <td>Advanced Engineering Informatics</td>
#     </tr>
#     <tr>
#       <td>3.0</td>
#       <td>Model</td>
#       <td></td>
#       <td>GNNExplainer: Generating Explanations for Graph Neural Networks</td>
#       <td></td>
#       <td>arXiv</td>
#     </tr>
#     <tr>
#       <td>4.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>A Spatial-Temporal Graph Based Hybrid Infectious Disease Model with Application to COVID-19</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>5.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>Spatial Visualization of Cluster-Specific COVID-19 Transmission Network in South Korea During the Early Epidemic Phase</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>6.0</td>
#       <td>Model</td>
#       <td>Traffic</td>
#       <td>Graph-GAN: A spatial-temporal neural network for short-term passenger flow prediction in urban rail transit systems</td>
#       <td>9.69</td>
#       <td>transportation research part c</td>
#     </tr>
#     <tr>
#       <td>7.0</td>
#       <td></td>
#       <td>Traffic</td>
#       <td>EXPLAINABLE GRAPH PYRAMID AUTOFORMER FOR LONG-TERM TRAFFIC FORECASTING</td>
#       <td></td>
#       <td>arXiv</td>
#     </tr>
#     <tr>
#       <td>8.0</td>
#       <td>Model</td>
#       <td>Covid</td>
#       <td>Transfer Graph Neural Networks for Pandemic Forecasting</td>
#       <td></td>
#       <td>The Thirty-Fifth AAAI Conference on Artificial Intelligence (AAAI-21)</td>
#     </tr>
#     <tr>
#       <td>9.0</td>
#       <td>python library</td>
#       <td></td>
#       <td>PyTorch Geometric Temporal: Spatiotemporal Signal Processing with Neural Machine Learning Models</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>10.0</td>
#       <td>Model</td>
#       <td>Covid</td>
#       <td>Data-Driven Time Series Forecasting for Social Studies Using Spatio-Temporal Graph Neural Networks</td>
#       <td></td>
#       <td>Proceedings of the Conference on Information Technology for Social Good. 2021.</td>
#     </tr>
#     <tr>
#       <td>11.0</td>
#       <td>Model</td>
#       <td>Covid</td>
#       <td>Hierarchical Spatio-Temporal Graph Neural Networks for Pandemic Forecasting</td>
#       <td></td>
#       <td>Proceedings of the 31st ACM International Conference on Information &amp; Knowledge Management. 2022.</td>
#     </tr>
#     <tr>
#       <td>12.0</td>
#       <td>Graph Theory</td>
#       <td>Brain</td>
#       <td>A Graph Theory-Based Modeling of Functional Brain Connectivity Based on EEG: A Systematic Review in the Context of Neuroergonomics</td>
#       <td>4.34</td>
#       <td>IEEE Access</td>
#     </tr>
#     <tr>
#       <td>13.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>A Model for COVID-19 Prediction Based on Spatio-temporal Convolutional Network</td>
#       <td></td>
#       <td>2022 International Joint Conference on Neural Networks (IJCNN). IEEE, 2022.</td>
#     </tr>
#     <tr>
#       <td>14.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>An Artificial Neural Network-Based Approach for Predicting the COVID-19 Daily Effective Reproduction Number Rt in Italy</td>
#       <td></td>
#       <td>MDPI AI</td>
#     </tr>
#     <tr>
#       <td>15.0</td>
#       <td>Model</td>
#       <td>Covid</td>
#       <td>CausalGNN: Causal-based Graph Neural Networks for Spatio-Temporal Epidemic Forecasting</td>
#       <td></td>
#       <td>The AAAI Digital Library will contain the published version some time after the conference.</td>
#     </tr>
#     <tr>
#       <td>16.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>Predicting the Dynamics of the COVID-19 Pandemic in the United States Using Graph Theory-Based Neural Networks</td>
#       <td>4.614</td>
#       <td>MDPI IJERPH</td>
#     </tr>
#     <tr>
#       <td>17.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>An Epidemiological Neural Network Exploiting Dynamic Graph Structured Data Applied to the COVID-19 Outbreak</td>
#       <td>2.6</td>
#       <td>IEEE TRANSACTIONS ON BIG DATA, VOL. 7, NO. 1, JANUARY-MARCH 2021</td>
#     </tr>
#     <tr>
#       <td>18.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>Analysis of the Spatio-Temporal Dynamics of COVID-19 in Massachusetts via Spectral Graph Wavelet Theory</td>
#       <td>3.301</td>
#       <td>IEEE TRANSACTIONS ON SIGNAL AND INFORMATION PROCESSING OVER NETWORKS, VOL. 8, 2022</td>
#     </tr>
#     <tr>
#       <td>19.0</td>
#       <td>Covid Forecasting</td>
#       <td>Covid</td>
#       <td>Forecasting of COVID19 per regions using ARIMA models and polynomial functions</td>
#       <td>6.725</td>
#       <td>Applied Soft Computing Journal</td>
#     </tr>
#     <tr>
#       <td>20.0</td>
#       <td>Covid Forecasting</td>
#       <td>Covid</td>
#       <td>ARIMA modelling &amp; forecasting of COVID-19 in top five affected countries</td>
#       <td>8.38</td>
#       <td>Diabetes &amp; Metabolic Syndrome: Clinical Research &amp; Reviews</td>
#     </tr>
#     <tr>
#       <td>21.0</td>
#       <td>Model</td>
#       <td>Traffic</td>
#       <td>Attention Based Spatial-Temporal Graph Convolutional Networks for Traffic Flow Forecasting</td>
#       <td></td>
#       <td>Association for the Advancement of Artificial Intelligence (www.aaai.org). All rights reserved.</td>
#     </tr>
#     <tr>
#       <td>22.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>The COVID-19 Infection Diffusion in the US and Japan: A Graph-Theoretical Approach</td>
#       <td>5.168</td>
#       <td>MDPI biology</td>
#     </tr>
#     <tr>
#       <td>23.0</td>
#       <td></td>
#       <td>Crop Yield</td>
#       <td>A GNN-RNN Approach for Harnessing Geospatial and Temporal Information: Application to Crop Yield Prediction</td>
#       <td></td>
#       <td>The Thirty-Sixth AAAI Conference on Artificial Intelligence (AAAI-22)</td>
#     </tr>
#     <tr>
#       <td>24.0</td>
#       <td>Graph Theory</td>
#       <td>Covid</td>
#       <td>COVID-19 - A Graph Network Approach</td>
#       <td></td>
#       <td>SMU Data Science Review 5.3 (2021): 1.</td>
#     </tr>
#     <tr>
#       <td>25.0</td>
#       <td>Graph Theory</td>
#       <td>Brain</td>
#       <td>Application of Graph Theory for Identifying Connectivity Patterns in Human Brain Networks: A Systematic Review</td>
#       <td>5.152</td>
#       <td>frontiers in Neuroscience</td>
#     </tr>
#     <tr>
#       <td>26.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>Data-driven dynamic clustering framework for mitigating the adverse T economic impact of Covid-19 lockdown practices</td>
#       <td>10.696</td>
#       <td>Sustainable Cities and Society</td>
#     </tr>
#     <tr>
#       <td>27.0</td>
#       <td>Model</td>
#       <td>Traffic</td>
#       <td>DIFFUSION CONVOLUTIONAL RECURRENT NEURAL NETWORK: DATA-DRIVEN TRAFFIC FORECASTING</td>
#       <td></td>
#       <td>arXiv</td>
#     </tr>
#     <tr>
#       <td>28.0</td>
#       <td>Dynamic Graph</td>
#       <td>Traffic</td>
#       <td>Dynamic Spatial-Temporal Graph Convolutional Neural Networks for Traffic Forecasting</td>
#       <td></td>
#       <td>arXiv</td>
#     </tr>
#     <tr>
#       <td>29.0</td>
#       <td>Model</td>
#       <td></td>
#       <td>DROPEDGE: TOWARDS DEEP GRAPH CONVOLU- TIONAL NETWORKS ON NODE CLASSIFICATION</td>
#       <td></td>
#       <td>arXiv</td>
#     </tr>
#     <tr>
#       <td>30.0</td>
#       <td>Dynamic Graph</td>
#       <td>Covid</td>
#       <td>Dynamic graph based epidemiological model for COVID-19 contact tracing data analysis and optimal testing prescription</td>
#       <td></td>
#       <td>arXiv</td>
#     </tr>
#     <tr>
#       <td>31.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>Dynamic graph in a symbolic data framework: An account of the causal relation using COVID-19 reports and some reflections on the financial world</td>
#       <td>9.922</td>
#       <td>Chaos, Solitons and Fractals</td>
#     </tr>
#     <tr>
#       <td>32.0</td>
#       <td>XAI</td>
#       <td></td>
#       <td>Machine Learning Interpretability: A Survey on Methods and Metrics</td>
#       <td>2.69</td>
#       <td>MDPI eletronics</td>
#     </tr>
#     <tr>
#       <td>33.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>Enhance COVID-19 Mortality Prediction with Human Mobility Trend and Medical Information</td>
#       <td></td>
#       <td>2021 IEEE 23rd Int Conf on High Performance Computing &amp; Communications; 7th Int Conf on Data Science &amp; Systems; 19th Int Conf on Smart City; 7th Int Conf on Dependability in Sensor, Cloud &amp; Big Data Systems &amp; Application</td>
#     </tr>
#     <tr>
#       <td>34.0</td>
#       <td>Model</td>
#       <td></td>
#       <td>Explainable AI: A Review of Machine Learning Interpretability Methods</td>
#       <td>2.738</td>
#       <td>MDPI entropy</td>
#     </tr>
#     <tr>
#       <td>35.0</td>
#       <td>Model</td>
#       <td>Covid</td>
#       <td>EpiGNN: Exploring Spatial Transmission with Graph Neural Network for Regional Epidemic Forecasting</td>
#       <td></td>
#       <td>arXiv</td>
#     </tr>
#     <tr>
#       <td>36.0</td>
#       <td>Dynamic Graph</td>
#       <td></td>
#       <td>EvolveGCN: Evolving Graph Convolutional Networks for Dynamic Graphs</td>
#       <td></td>
#       <td>The Thirty-Fourth AAAI Conference on Artificial Intelligence (AAAI-20)</td>
#     </tr>
#     <tr>
#       <td>37.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>Examining COVID-19 Forecasting using Spatio-Temporal Graph Neural Networks</td>
#       <td></td>
#       <td>arXiv</td>
#     </tr>
#     <tr>
#       <td>38.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>Risk Assessment and Prediction of COVID-19 Based on Epidemiological Data From Spatiotemporal Geography</td>
#       <td>5.411</td>
#       <td>frontiers in Environmental Science</td>
#     </tr>
#     <tr>
#       <td>39.0</td>
#       <td>Model</td>
#       <td></td>
#       <td>HOW POWERFUL ARE GRAPH NEURAL NETWORKS?</td>
#       <td></td>
#       <td>Published as a conference paper at ICLR 2019</td>
#     </tr>
#     <tr>
#       <td>40.0</td>
#       <td>Graph Theory</td>
#       <td></td>
#       <td>Graph Signal Processing Overview, Challenges, and Applications</td>
#       <td>14.91</td>
#       <td>Proceedings of the IEEE</td>
#     </tr>
#     <tr>
#       <td>41.0</td>
#       <td>Model</td>
#       <td></td>
#       <td>SEMI-SUPERVISED CLASSIFICATION WITH GRAPH CONVOLUTIONAL NETWORKS</td>
#       <td></td>
#       <td>arXiv</td>
#     </tr>
#     <tr>
#       <td>42.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>Prediction of the confirmed cases and deaths of global COVID-19 using artificial intelligence</td>
#       <td>5.053</td>
#       <td>Environmental Science and Pollution Research</td>
#     </tr>
#     <tr>
#       <td>43.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>The Chaotic Behavior of the Spread of Infection during the COVID-19 Pandemic in Japan</td>
#       <td>4.614</td>
#       <td>MDPI IJERPH</td>
#     </tr>
#     <tr>
#       <td>44.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>Developing an artificial neural network for detecting COVID‐19 disease</td>
#       <td></td>
#       <td>2022 Journal of Education and Health Promotion</td>
#     </tr>
#     <tr>
#       <td>45.0</td>
#       <td>Covid Forecasting</td>
#       <td>Covid</td>
#       <td>Forecasting COVID-19 confirmed cases in South Korea using Spatio-Temporal Graph Neural Networks</td>
#       <td></td>
#       <td>the korea contents association</td>
#     </tr>
#     <tr>
#       <td>46.0</td>
#       <td>Covid Forecasting</td>
#       <td>Covid</td>
#       <td>Time series forecasting of COVID-19 transmission in Canada using LSTM networks</td>
#       <td>9.922</td>
#       <td>Chaos, Solitons and Fractals</td>
#     </tr>
#     <tr>
#       <td>47.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>Predictions for COVID-19 with deep learning models of LSTM, GRU and Bi-LSTM</td>
#       <td>9.922</td>
#       <td>Chaos, Solitons and Fractals</td>
#     </tr>
#     <tr>
#       <td>48.0</td>
#       <td>Model</td>
#       <td></td>
#       <td>Long Short-Term Memory</td>
#       <td>2.026</td>
#       <td>Neural Computation</td>
#     </tr>
#     <tr>
#       <td>49.0</td>
#       <td>Covid Forecasting</td>
#       <td>Covid</td>
#       <td>Integrating LSTMs and GNNs for COVID-19 Forecasting</td>
#       <td></td>
#       <td>arXiv</td>
#     </tr>
#     <tr>
#       <td>50.0</td>
#       <td>Covid Forecasting</td>
#       <td>Covid</td>
#       <td>Multiwave COVID-19 Prediction from Social Awareness using Web Search and Mobility Data</td>
#       <td></td>
#       <td>Proceedings of the 28th ACM SIGKDD Conference on Knowledge Discovery and Data Mining. 2022</td>
#     </tr>
#     <tr>
#       <td>51.0</td>
#       <td>Model</td>
#       <td>Quantum</td>
#       <td>Neural Message Passing for Quantum Chemistry</td>
#       <td></td>
#       <td>International conference on machine learning. PMLR, 2017.</td>
#     </tr>
#     <tr>
#       <td>52.0</td>
#       <td>Model</td>
#       <td>Covid</td>
#       <td>Non-separable Spatio-temporal Graph Kernels via SPDEs</td>
#       <td></td>
#       <td>International Conference on Artificial Intelligence and Statistics. PMLR, 2022.</td>
#     </tr>
#     <tr>
#       <td>53.0</td>
#       <td>Model</td>
#       <td>Covid</td>
#       <td>STAN: spatio-temporal attention network for pandemic prediction using real-world evidence</td>
#       <td>7.942</td>
#       <td>Journal of the American Medical Informatics Association 28.4 (2021): 733-743</td>
#     </tr>
#     <tr>
#       <td>54.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>Trend estimation and short-term forecasting of COVID-19 cases and deaths worldwide</td>
#       <td>13.45</td>
#       <td>PNAS</td>
#     </tr>
#     <tr>
#       <td>55.0</td>
#       <td>Dynamic Graph</td>
#       <td></td>
#       <td>Predictive Temporal Embedding of Dynamic Graphs</td>
#       <td></td>
#       <td>2019 IEEE/ACM International Conference on Advances in Social Networks Analysis and Mining</td>
#     </tr>
#     <tr>
#       <td>56.0</td>
#       <td>Model</td>
#       <td></td>
#       <td>A Graph Convolutional Incorporating GRU Network for Landslide Displacement Forecasting Based on Spatiotemporal Analysis of GNSS Observations</td>
#       <td>5.349</td>
#       <td>MDPI remote sensing</td>
#     </tr>
#     <tr>
#       <td>57.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>A proficient approach to forecast COVID‐19 spread via optimized dynamic machine learning models</td>
#       <td>5.516</td>
#       <td>scientific reports</td>
#     </tr>
#     <tr>
#       <td>58.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>Spatiotemporal impacts of human activities and socio-demographics during the COVID-19 outbreak in the US</td>
#       <td>4.545</td>
#       <td>bmc public health</td>
#     </tr>
#     <tr>
#       <td>59.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>Combining graph neural networks and spatio‐temporal disease models to improve the prediction of weekly COVID‐19 cases in Germany</td>
#       <td>5.516</td>
#       <td>scientific reports</td>
#     </tr>
#     <tr>
#       <td>60.0</td>
#       <td>Dynamic Graph</td>
#       <td></td>
#       <td>SDG: A Simplified and Dynamic Graph Neural Network</td>
#       <td></td>
#       <td>SIGIR ’21, July 11–15, 2021, Virtual Event, Canada</td>
#     </tr>
#     <tr>
#       <td>61.0</td>
#       <td></td>
#       <td>Seismic</td>
#       <td>Graph neural networks for multivariate time series regression with application to seismic data</td>
#       <td>2.52</td>
#       <td>International Journal of Data Science and Analytics</td>
#     </tr>
#     <tr>
#       <td>62.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>Deep Spatiotemporal Model for COVID-19 Forecasting</td>
#       <td>3.847</td>
#       <td>MDPI sensors</td>
#     </tr>
#     <tr>
#       <td>63.0</td>
#       <td>Model</td>
#       <td></td>
#       <td>Simple and Deep Graph Convolutional Networks</td>
#       <td></td>
#       <td>arXiv</td>
#     </tr>
#     <tr>
#       <td>64.0</td>
#       <td>Model</td>
#       <td>Traffic</td>
#       <td>Spatio-Temporal Graph Convolutional Networks: A Deep Learning Framework for Traffic Forecasting</td>
#       <td></td>
#       <td>arXiv</td>
#     </tr>
#     <tr>
#       <td>65.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>Research on the Forecast of the Spread of COVID-19</td>
#       <td></td>
#       <td>2021 11th International Conference on Biomedical Engineering and Technology (ICBET ’21),</td>
#     </tr>
#     <tr>
#       <td>66.0</td>
#       <td>Model</td>
#       <td>Covid</td>
#       <td>MepoGNN: Metapopulation Epidemic Forecasting with Graph Neural Networks</td>
#       <td></td>
#       <td>2022.ecmlpkdd.org</td>
#     </tr>
#     <tr>
#       <td>67.0</td>
#       <td>Model</td>
#       <td>Covid</td>
#       <td>TAMP-S2GCNETS: COUPLING TIME-AWARE MUL- TIPERSISTENCE KNOWLEDGE REPRESENTATION WITH SPATIO-SUPRA GRAPH CONVOLUTIONAL NETWORKS FOR TIME-SERIES FORECASTING</td>
#       <td></td>
#       <td>conference paper at ICLR 2022</td>
#     </tr>
#     <tr>
#       <td>68.0</td>
#       <td>Model</td>
#       <td></td>
#       <td>TeGraph: A Novel General-Purpose Temporal Graph Computing Engine</td>
#       <td></td>
#       <td>2022 IEEE 38th International Conference on Data Engineering (ICDE)</td>
#     </tr>
#     <tr>
#       <td>69.0</td>
#       <td>Model</td>
#       <td>Traffic</td>
#       <td>T-GCN: A Temporal Graph Convolutional Network for Traffic Prediction</td>
#       <td>9.551</td>
#       <td>IEEE Transactions on Intelligent Transportation Systems</td>
#     </tr>
#     <tr>
#       <td>70.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>Transfer Graph Neural Networks for Pandemic Forecasting</td>
#       <td></td>
#       <td>arXiv</td>
#     </tr>
#     <tr>
#       <td>71.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>Use of Artificial Intelligence on spatio-temporal data to generate insights during COVID-19 pandemic: A Review</td>
#       <td></td>
#       <td>medRxiv</td>
#     </tr>
#     <tr>
#       <td>72.0</td>
#       <td></td>
#       <td>Hydrology</td>
#       <td>Explore Spatio-Temporal Learning of Large Sample Hydrology Using Graph Neural Networks</td>
#       <td>6.16</td>
#       <td>Water Resources Research</td>
#     </tr>
#     <tr>
#       <td>73.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>Transportation, germs, culture: a dynamic graph model of COVID-19 outbreak</td>
#       <td>3.54</td>
#       <td>Quantitative Biology</td>
#     </tr>
#     <tr>
#       <td>74.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>Spatiotemporal dynamic network for regional maritime vessel flow prediction amid COVID-19</td>
#       <td></td>
#       <td>Transport Policy</td>
#     </tr>
#     <tr>
#       <td>75.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>An ensemble model based on early predictors to forecast COVID-19 health care demand in France</td>
#       <td></td>
#       <td>PNAS</td>
#     </tr>
#     <tr>
#       <td>76.0</td>
#       <td>Graph Theory</td>
#       <td>climate</td>
#       <td>Network-based forecasting of climate phenomena</td>
#       <td></td>
#       <td>PNAS</td>
#     </tr>
#     <tr>
#       <td>77.0</td>
#       <td></td>
#       <td></td>
#       <td>Prediction of arrhythmia susceptibility through mathematical modeling and machine learning</td>
#       <td></td>
#       <td>PNAS</td>
#     </tr>
#     <tr>
#       <td>78.0</td>
#       <td></td>
#       <td>Covid</td>
#       <td>The impact of social isolation and changes in work patterns on ongoing thought during the first COVID-19 lockdown in the United Kingdom</td>
#       <td></td>
#       <td>PNAS</td>
#     </tr>
#     <tr>
#       <td>79.0</td>
#       <td></td>
#       <td></td>
#       <td>Fundamental limitations on efficiently forecasting certain epidemic measures in network models</td>
#       <td></td>
#       <td>arXiv</td>
#     </tr>
#   </tbody>
# </table>

# %%
res = qa({'query' : 'Covid 도메인의 논문이름 알려줘'})
# k를 어떻게 설정해야 할까. streamlit의 인풋으로줘야할까?
res['result'], res['source_documents']
# Out:
# ('\nThe Impact of Weather Condition and Social Activity on COVID-19 Transmission in the United States: An Epidemiological Neural Network Exploiting Dynamic Graph Structured Data Applied to the COVID-19 Outbreak, as published in the AAAI Digital Library.  Predicting the Dynamics of the COVID-19 Pandemic in the United States Using Graph Theory-Based Neural Networks, as published in MDPI IJERPH. The COVID-19 Infection Diffusion in the US and Japan: A Graph-Theoretical Approach, as published in MDPI Biology.',
#  [Document(page_content='주제\n도메인\n논문명\nIF\n저널명\n1.0\nCovid, weather\nThe impact of weather condition and social activity on COVID-19 transmission in the United States\n6.789\nJournal of Environmental Management\n2.0\nCovid', metadata={'source': '/Users/jeonjunhwi/문서/Projects/GNN_Covid/refference/GNN 논문리스트.xlsx', 'filename': 'GNN 논문리스트.xlsx', 'file_directory': '/Users/jeonjunhwi/문서/Projects/GNN_Covid/refference', 'last_modified': '2023-10-22T20:42:38', 'filetype': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'languages': ['eng'], 'page_number': 1, 'page_name': 'Sheet1', 'text_as_html': '<table border="1" class="dataframe">\n  <tbody>\n    <tr>\n      <td></td>\n      <td>주제</td>\n      <td>도메인</td>\n      <td>논문명</td>\n      <td>IF</td>\n      <td>저널명</td>\n    </tr>\n    <tr>\n      <td>1.0</td>\n      <td></td>\n      <td>Covid, weather</td>\n      <td>The impact of weather condition and social activity on COVID-19 transmission in the United States</td>\n      <td>6.789</td>\n      <td>Journal of Environmental Management</td>\n    </tr>\n    <tr>\n      <td>2.0</td>\n      <td></td>\n      <td>Covid</td>\n      <td>A deep spatio-temporal meta-learning model for urban traffic revitalization index prediction in the COVID-19 pandemic</td>\n      <td>5.603</td>\n      <td>Advanced Engineering Informatics</td>\n    </tr>\n    <tr>\n      <td>3.0</td>\n      <td>Model</td>\n      <td></td>\n      <td>GNNExplainer: Generating Explanations for Graph Neural Networks</td>\n      <td></td>\n      <td>arXiv</td>\n    </tr>\n    <tr>\n      <td>4.0</td>\n      <td></td>\n      <td>Covid</td>\n      <td>A Spatial-Temporal Graph Based Hybrid Infectious Disease Model with Application to COVID-19</td>\n      <td></td>\n      <td></td>\n    </tr>\n    <tr>\n      <td>5.0</td>\n      <td></td>\n      <td>Covid</td>\n      <td>Spatial Visualization of Cluster-Specific COVID-19 Transmission Network in South Korea During the Early Epidemic Phase</td>\n      <td></td>\n      <td></td>\n    </tr>\n    <tr>\n      <td>6.0</td>\n      <td>Model</td>\n      <td>Traffic</td>\n      <td>Graph-GAN: A spatial-temporal neural network for short-term passenger flow prediction in urban rail transit systems</td>\n      <td>9.69</td>\n      <td>transportation research part c</td>\n    </tr>\n    <tr>\n      <td>7.0</td>\n      <td></td>\n      <td>Traffic</td>\n      <td>EXPLAINABLE GRAPH PYRAMID AUTOFORMER FOR LONG-TERM TRAFFIC FORECASTING</td>\n      <td></td>\n      <td>arXiv</td>\n    </tr>\n    <tr>\n      <td>8.0</td>\n      <td>Model</td>\n      <td>Covid</td>\n      <td>Transfer Graph Neural Networks for Pandemic Forecasting</td>\n      <td></td>\n      <td>The Thirty-Fifth AAAI Conference on Artificial Intelligence (AAAI-21)</td>\n    </tr>\n    <tr>\n      <td>9.0</td>\n      <td>python library</td>\n      <td></td>\n      <td>PyTorch Geometric Temporal: Spatiotemporal Signal Processing with Neural Machine Learning Models</td>\n      <td></td>\n      <td></td>\n    </tr>\n    <tr>\n      <td>10.0</td>\n      <td>Model</td>\n      <td>Covid</td>\n      <td>Data-Driven Time Series Forecasting for Social Studies Using Spatio-Temporal Graph Neural Networks</td>\n      <td></td>\n      <td>Proceedings of the Conference on Information Technology for Social Good. 2021.</td>\n    </tr>\n    <tr>\n      <td>11.0</td>\n      <td>Model</td>\n      <td>Covid</td>\n      <td>Hierarchical Spatio-Temporal Graph Neural Networks for Pandemic Forecasting</td>\n      <td></td>\n      <td>Proceedings of the 31st ACM International Conference on Information &amp; Knowledge Management. 2022.</td>\n    </tr>\n    <tr>\n      <td>12.0</td>\n      <td>Graph Theory</td>\n      <td>Brain</td>\n      <td>A Graph Theory-Based Modeling of Functional Brain Connectivity Based on EEG: A Systematic Review in the Context of Neuroergonomics</td>\n      <td>4.34</td>\n      <td>IEEE Access</td>\n    </tr>\n    <tr>\n      <td>13.0</td>\n      <td></td>\n       ...
#   Document(page_content='4.614\nMDPI IJERPH\n17.0\nCovid\nAn Epidemiological Neural Network Exploiting Dynamic Graph Structured Data Applied to the COVID-19 Outbreak\n2.6\nIEEE TRANSACTIONS ON BIG DATA, VOL. 7, NO. 1, JANUARY-MARCH 2021\n18.0\nCovid', metadata={'source': '/Users/jeonjunhwi/문서/Projects/GNN_Covid/refference/GNN 논문리스트.xlsx', 'filename': 'GNN 논문리스트.xlsx', 'file_directory': '/Users/jeonjunhwi/문서/Projects/GNN_Covid/refference', 'last_modified': '2023-10-22T20:42:38', 'filetype': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'languages': ['eng'], 'page_number': 1, 'page_name': 'Sheet1', 'text_as_html': '<table border="1" class="dataframe">\n  <tbody>\n    <tr>\n      <td></td>\n      <td>주제</td>\n      <td>도메인</td>\n      <td>논문명</td>\n      <td>IF</td>\n      <td>저널명</td>\n    </tr>\n    <tr>\n      <td>1.0</td>\n      <td></td>\n      <td>Covid, weather</td>\n      <td>The impact of weather condition and social activity on COVID-19 transmission in the United States</td>\n      <td>6.789</td>\n      <td>Journal of Environmental Management</td>\n    </tr>\n    <tr>\n      <td>2.0</td>\n      <td></td>\n      <td>Covid</td>\n      <td>A deep spatio-temporal meta-learning model for urban traffic revitalization index prediction in the COVID-19 pandemic</td>\n      <td>5.603</td>\n      <td>Advanced Engineering Informatics</td>\n    </tr>\n    <tr>\n      <td>3.0</td>\n      <td>Model</td>\n      <td></td>\n      <td>GNNExplainer: Generating Explanations for Graph Neural Networks</td>\n      <td></td>\n      <td>arXiv</td>\n    </tr>\n    <tr>\n      <td>4.0</td>\n      <td></td>\n      <td>Covid</td>\n      <td>A Spatial-Temporal Graph Based Hybrid Infectious Disease Model with Application to COVID-19</td>\n      <td></td>\n      <td></td>\n    </tr>\n    <tr>\n      <td>5.0</td>\n      <td></td>\n      <td>Covid</td>\n      <td>Spatial Visualization of Cluster-Specific COVID-19 Transmission Network in South Korea During the Early Epidemic Phase</td>\n      <td></td>\n      <td></td>\n    </tr>\n    <tr>\n      <td>6.0</td>\n      <td>Model</td>\n      <td>Traffic</td>\n      <td>Graph-GAN: A spatial-temporal neural network for short-term passenger flow prediction in urban rail transit systems</td>\n      <td>9.69</td>\n      <td>transportation research part c</td>\n    </tr>\n    <tr>\n      <td>7.0</td>\n      <td></td>\n      <td>Traffic</td>\n      <td>EXPLAINABLE GRAPH PYRAMID AUTOFORMER FOR LONG-TERM TRAFFIC FORECASTING</td>\n      <td></td>\n      <td>arXiv</td>\n    </tr>\n    <tr>\n      <td>8.0</td>\n      <td>Model</td>\n      <td>Covid</td>\n      <td>Transfer Graph Neural Networks for Pandemic Forecasting</td>\n      <td></td>\n      <td>The Thirty-Fifth AAAI Conference on Artificial Intelligence (AAAI-21)</td>\n    </tr>\n    <tr>\n      <td>9.0</td>\n      <td>python library</td>\n      <td></td>\n      <td>PyTorch Geometric Temporal: Spatiotemporal Signal Processing with Neural Machine Learning Models</td>\n      <td></td>\n      <td></td>\n    </tr>\n    <tr>\n      <td>10.0</td>\n      <td>Model</td>\n      <td>Covid</td>\n      <td>Data-Driven Time Series Forecasting for Social Studies Using Spatio-Temporal Graph Neural Networks</td>\n      <td></td>\n      <td>Proceedings of the Conference on Information Technology for Social Good. 2021.</td>\n    </tr>\n    <tr>\n      <td>11.0</td>\n      <td>Model</td>\n      <td>Covid</td>\n      <td>Hierarchical Spatio-Temporal Graph Neural Networks for Pandemic Forecasting</td>\n      <td></td>\n      <td>Proceedings of the 31st ACM International Conference on Information &amp; Knowledge Management. 2022.</td>\n    </tr>\n    <tr>\n      <td>12.0</td>\n      <td>Graph Theory</td>\n      <td>Brain</td>\n      <td>A Graph Theory-Based Modeling of Functional Brain Connectivity Based on EEG: A Systematic Review in the Context of Neuroergonomics</td>\n      <td>4.34</td>\n      <td>IEEE Access</td>\n    </tr>\n    <tr>\n      <td>13.0</t ...
#   Document(page_content='The AAAI Digital Library will contain the published version some time after the conference.\n16.0\nCovid\nPredicting the Dynamics of the COVID-19 Pandemic in the United States Using Graph Theory-Based Neural Networks\n4.614\nMDPI IJERPH\n17.0\nCovid', metadata={'source': '/Users/jeonjunhwi/문서/Projects/GNN_Covid/refference/GNN 논문리스트.xlsx', 'filename': 'GNN 논문리스트.xlsx', 'file_directory': '/Users/jeonjunhwi/문서/Projects/GNN_Covid/refference', 'last_modified': '2023-10-22T20:42:38', 'filetype': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'languages': ['eng'], 'page_number': 1, 'page_name': 'Sheet1', 'text_as_html': '<table border="1" class="dataframe">\n  <tbody>\n    <tr>\n      <td></td>\n      <td>주제</td>\n      <td>도메인</td>\n      <td>논문명</td>\n      <td>IF</td>\n      <td>저널명</td>\n    </tr>\n    <tr>\n      <td>1.0</td>\n      <td></td>\n      <td>Covid, weather</td>\n      <td>The impact of weather condition and social activity on COVID-19 transmission in the United States</td>\n      <td>6.789</td>\n      <td>Journal of Environmental Management</td>\n    </tr>\n    <tr>\n      <td>2.0</td>\n      <td></td>\n      <td>Covid</td>\n      <td>A deep spatio-temporal meta-learning model for urban traffic revitalization index prediction in the COVID-19 pandemic</td>\n      <td>5.603</td>\n      <td>Advanced Engineering Informatics</td>\n    </tr>\n    <tr>\n      <td>3.0</td>\n      <td>Model</td>\n      <td></td>\n      <td>GNNExplainer: Generating Explanations for Graph Neural Networks</td>\n      <td></td>\n      <td>arXiv</td>\n    </tr>\n    <tr>\n      <td>4.0</td>\n      <td></td>\n      <td>Covid</td>\n      <td>A Spatial-Temporal Graph Based Hybrid Infectious Disease Model with Application to COVID-19</td>\n      <td></td>\n      <td></td>\n    </tr>\n    <tr>\n      <td>5.0</td>\n      <td></td>\n      <td>Covid</td>\n      <td>Spatial Visualization of Cluster-Specific COVID-19 Transmission Network in South Korea During the Early Epidemic Phase</td>\n      <td></td>\n      <td></td>\n    </tr>\n    <tr>\n      <td>6.0</td>\n      <td>Model</td>\n      <td>Traffic</td>\n      <td>Graph-GAN: A spatial-temporal neural network for short-term passenger flow prediction in urban rail transit systems</td>\n      <td>9.69</td>\n      <td>transportation research part c</td>\n    </tr>\n    <tr>\n      <td>7.0</td>\n      <td></td>\n      <td>Traffic</td>\n      <td>EXPLAINABLE GRAPH PYRAMID AUTOFORMER FOR LONG-TERM TRAFFIC FORECASTING</td>\n      <td></td>\n      <td>arXiv</td>\n    </tr>\n    <tr>\n      <td>8.0</td>\n      <td>Model</td>\n      <td>Covid</td>\n      <td>Transfer Graph Neural Networks for Pandemic Forecasting</td>\n      <td></td>\n      <td>The Thirty-Fifth AAAI Conference on Artificial Intelligence (AAAI-21)</td>\n    </tr>\n    <tr>\n      <td>9.0</td>\n      <td>python library</td>\n      <td></td>\n      <td>PyTorch Geometric Temporal: Spatiotemporal Signal Processing with Neural Machine Learning Models</td>\n      <td></td>\n      <td></td>\n    </tr>\n    <tr>\n      <td>10.0</td>\n      <td>Model</td>\n      <td>Covid</td>\n      <td>Data-Driven Time Series Forecasting for Social Studies Using Spatio-Temporal Graph Neural Networks</td>\n      <td></td>\n      <td>Proceedings of the Conference on Information Technology for Social Good. 2021.</td>\n    </tr>\n    <tr>\n      <td>11.0</td>\n      <td>Model</td>\n      <td>Covid</td>\n      <td>Hierarchical Spatio-Temporal Graph Neural Networks for Pandemic Forecasting</td>\n      <td></td>\n      <td>Proceedings of the 31st ACM International Conference on Information &amp; Knowledge Management. 2022.</td>\n    </tr>\n    <tr>\n      <td>12.0</td>\n      <td>Graph Theory</td>\n      <td>Brain</td>\n      <td>A Graph Theory-Based Modeling of Functional Brain Connectivity Based on EEG: A Systematic Review in the Context of Neuroergonomics</td>\n      <td>4.34</td>\n      <td>IEEE Access</td>\n    </tr>\n   ...
#   Document(page_content='Association for the Advancement of Artificial Intelligence (www.aaai.org). All rights reserved.\n22.0\nCovid\nThe COVID-19 Infection Diffusion in the US and Japan: A Graph-Theoretical Approach\n5.168\nMDPI biology\n23.0\nCrop Yield', metadata={'source': '/Users/jeonjunhwi/문서/Projects/GNN_Covid/refference/GNN 논문리스트.xlsx', 'filename': 'GNN 논문리스트.xlsx', 'file_directory': '/Users/jeonjunhwi/문서/Projects/GNN_Covid/refference', 'last_modified': '2023-10-22T20:42:38', 'filetype': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'languages': ['eng'], 'page_number': 1, 'page_name': 'Sheet1', 'text_as_html': '<table border="1" class="dataframe">\n  <tbody>\n    <tr>\n      <td></td>\n      <td>주제</td>\n      <td>도메인</td>\n      <td>논문명</td>\n      <td>IF</td>\n      <td>저널명</td>\n    </tr>\n    <tr>\n      <td>1.0</td>\n      <td></td>\n      <td>Covid, weather</td>\n      <td>The impact of weather condition and social activity on COVID-19 transmission in the United States</td>\n      <td>6.789</td>\n      <td>Journal of Environmental Management</td>\n    </tr>\n    <tr>\n      <td>2.0</td>\n      <td></td>\n      <td>Covid</td>\n      <td>A deep spatio-temporal meta-learning model for urban traffic revitalization index prediction in the COVID-19 pandemic</td>\n      <td>5.603</td>\n      <td>Advanced Engineering Informatics</td>\n    </tr>\n    <tr>\n      <td>3.0</td>\n      <td>Model</td>\n      <td></td>\n      <td>GNNExplainer: Generating Explanations for Graph Neural Networks</td>\n      <td></td>\n      <td>arXiv</td>\n    </tr>\n    <tr>\n      <td>4.0</td>\n      <td></td>\n      <td>Covid</td>\n      <td>A Spatial-Temporal Graph Based Hybrid Infectious Disease Model with Application to COVID-19</td>\n      <td></td>\n      <td></td>\n    </tr>\n    <tr>\n      <td>5.0</td>\n      <td></td>\n      <td>Covid</td>\n      <td>Spatial Visualization of Cluster-Specific COVID-19 Transmission Network in South Korea During the Early Epidemic Phase</td>\n      <td></td>\n      <td></td>\n    </tr>\n    <tr>\n      <td>6.0</td>\n      <td>Model</td>\n      <td>Traffic</td>\n      <td>Graph-GAN: A spatial-temporal neural network for short-term passenger flow prediction in urban rail transit systems</td>\n      <td>9.69</td>\n      <td>transportation research part c</td>\n    </tr>\n    <tr>\n      <td>7.0</td>\n      <td></td>\n      <td>Traffic</td>\n      <td>EXPLAINABLE GRAPH PYRAMID AUTOFORMER FOR LONG-TERM TRAFFIC FORECASTING</td>\n      <td></td>\n      <td>arXiv</td>\n    </tr>\n    <tr>\n      <td>8.0</td>\n      <td>Model</td>\n      <td>Covid</td>\n      <td>Transfer Graph Neural Networks for Pandemic Forecasting</td>\n      <td></td>\n      <td>The Thirty-Fifth AAAI Conference on Artificial Intelligence (AAAI-21)</td>\n    </tr>\n    <tr>\n      <td>9.0</td>\n      <td>python library</td>\n      <td></td>\n      <td>PyTorch Geometric Temporal: Spatiotemporal Signal Processing with Neural Machine Learning Models</td>\n      <td></td>\n      <td></td>\n    </tr>\n    <tr>\n      <td>10.0</td>\n      <td>Model</td>\n      <td>Covid</td>\n      <td>Data-Driven Time Series Forecasting for Social Studies Using Spatio-Temporal Graph Neural Networks</td>\n      <td></td>\n      <td>Proceedings of the Conference on Information Technology for Social Good. 2021.</td>\n    </tr>\n    <tr>\n      <td>11.0</td>\n      <td>Model</td>\n      <td>Covid</td>\n      <td>Hierarchical Spatio-Temporal Graph Neural Networks for Pandemic Forecasting</td>\n      <td></td>\n      <td>Proceedings of the 31st ACM International Conference on Information &amp; Knowledge Management. 2022.</td>\n    </tr>\n    <tr>\n      <td>12.0</td>\n      <td>Graph Theory</td>\n      <td>Brain</td>\n      <td>A Graph Theory-Based Modeling of Functional Brain Connectivity Based on EEG: A Systematic Review in the Context of Neuroergonomics</td>\n      <td>4.34</td>\n      <td>IEEE Access</td>\n    </tr>\n    <tr>\n      <td> ...

# %% [markdown]
# https://teddylee777.github.io/langchain/langchain-tutorial-04/
#
# 엑셀 말고 csv로 읽어와서 데이터프레임으로 만들어서 뭔가를 할 수 있음

# %% [markdown]
# Predicting the Dynamics of the COVID-19 Pandemic in the United States Using Graph Theory-Based Neural Networks,
#
# The COVID-19 Infection Diffusion in the US and Japan: A Graph-Theoretical Approach, Published in MDPI Biology;
#
# A Spatial-Temporal Graph Based Hybrid Infectious Disease Model with Application to COVID-19, Published on arXiv;
#
# Spatial Visualization of Cluster-Specific COVID-19 Transmission Network in South Korea During the Early Epidemic Phase, Published on arXiv;
#
# Traffic Model for COVID-19 Spread Prevention and Mitigation, Published on arXiv;
#
# Prediction of the confirmed cases and deaths of global COVID-19 using artificial intelligence, Published in Environmental Science and Pollution Research;
#
# COVID-19 Forecasting With Global AI-Powered Surveillance System, Published on arXiv;
#
# Forecasting COVID-19 confirmed cases in South Korea using Spatio-Temporal Graph Neural Networks, Published on the Korea Contents Association;
#
# The Prediction of COVID-19 Infection and Death Rates Using Artificial Intelligence, Published on ar # 임베딩 잘못됨
